# %% [markdown]
# # Forecasting Energy Production 2
#
# Step 2. The goal here is to create a range of features from our chosen variables that will be useful for our machine learning model.
# For now this will be the usual lags, rolling averages, cumulative totals and rates of change for all variables (except time obviously). I will then focus on training and validating the model. If I come back and make changes here after assessing the model I will highlight them.

# %%
import pandas as pd
import numpy as np

import fsspec

fs = fsspec.filesystem("")

# %%
import warnings
warnings.filterwarnings('ignore', category=pd.errors.PerformanceWarning) # bad form I know but this dataset is small enough for ugly code

# %%
df = pd.read_csv('data/forecast_data_cleaned.csv')
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
cols = list(df)
cols
# Out:
# ['temperature_2m',
#  'relative_humidity_2m',
#  'rain',
#  'cloud_cover_low',
#  'cloud_cover_mid',
#  'cloud_cover_high',
#  'wind_speed_10m',
#  'wind_speed_100m',
#  'wind_direction_10m',
#  'wind_direction_100m',
#  'direct_radiation',
#  'diffuse_radiation',
#  'power_x',
#  'TOD',
#  'TOD_sin',
#  'TOD_cos']

# %%
feature_cols = cols#[:-6]

# %%
feature_cols
# Out:
# ['temperature_2m',
#  'relative_humidity_2m',
#  'rain',
#  'cloud_cover_low',
#  'cloud_cover_mid',
#  'cloud_cover_high',
#  'wind_speed_10m',
#  'wind_speed_100m',
#  'wind_direction_10m',
#  'wind_direction_100m',
#  'direct_radiation',
#  'diffuse_radiation',
#  'power_x',
#  'TOD',
#  'TOD_sin',
#  'TOD_cos']

# %% [markdown]
# Some specific weather related features first up:

# %%
df['wind_speed_ratio'] = df['wind_speed_100m'] / df['wind_speed_10m'] # ratio of upper ws to lower ws

# wind shear is a great predictor of future weather and I imagine has implications for turbine productivity
df['wind_shear'] = np.log(df['wind_speed_100m'] / df['wind_speed_10m']) / np.log(100 / 10)

# wind speed components are sometimes easier for models than ws and direction
def wind_components(speed, direction):
    rad = np.radians(direction)
    u = -speed * np.sin(rad)
    v = -speed * np.cos(rad)
    return u, v

df['U_10m'], df['V_10m'] = wind_components(df['wind_speed_10m'], df['wind_direction_10m'])
df['U_100m'], df['V_100m'] = wind_components(df['wind_speed_100m'], df['wind_direction_100m'])

# magnitude of wind shear may be usefull
df['wind_shear_magnitude'] = np.sqrt((df['U_100m'] - df['U_10m'])**2 + (df['V_100m'] - df['V_10m'])**2) / (100 - 10)

# convert wind directions to cardinal bins to increase sample size. (in practice 355 deg wind is == 005 degree wind, given oscillations during gusts)
directions = ['N', 'NNE', 'NE', 'ENE', 'E', 'ESE', 'SE', 'SSE', 
              'S', 'SSW', 'SW', 'WSW', 'W', 'WNW', 'NW', 'NNW']
angles = np.linspace(0, 360, len(directions) + 1)  # Create bins

# Function to map wind direction to cardinal points
def wind_to_cardinal(angle):
    index = np.digitize([angle], angles, right=True)[0] % len(directions)
    return directions[index]

# Apply mapping
df["wind_direction_10m"] = df["wind_direction_10m"].apply(wind_to_cardinal)
df["wind_direction_100m"] = df["wind_direction_100m"].apply(wind_to_cardinal)

df["wind_direction_10m"] = df["wind_direction_10m"].astype("category").cat.codes
df["wind_direction_100m"] = df["wind_direction_100m"].astype("category").cat.codes

# %%
feature_cols = feature_cols + ['wind_speed_ratio', 'wind_shear', 'U_10m', 'U_100m', 'wind_shear_magnitude']

# %%
feature_cols
# Out:
# ['temperature_2m',
#  'relative_humidity_2m',
#  'rain',
#  'cloud_cover_low',
#  'cloud_cover_mid',
#  'cloud_cover_high',
#  'wind_speed_10m',
#  'wind_speed_100m',
#  'wind_direction_10m',
#  'wind_direction_100m',
#  'direct_radiation',
#  'diffuse_radiation',
#  'power_x',
#  'TOD',
#  'TOD_sin',
#  'TOD_cos',
#  'wind_speed_ratio',
#  'wind_shear',
#  'U_10m',
#  'U_100m',
#  'wind_shear_magnitude']

# %% [markdown]
# Lags, The LSTM model itself will inherintly have some lag knowledge built in but only over short horizons. I will include some extended horizons to enhance forecasting performance.

# %%
df = df.copy()
for col in feature_cols:
    for lag in [12, 24, 48, 72]:
        df[f'{col}_lag_{lag}'] = df[col].shift(lag)

# %% [markdown]
# Moving averages:

# %%
df = df.copy()
for col in feature_cols:
    for window in [2, 6, 12, 24, 48]:
        df[f'{col}_ma_{window}'] = df[col].rolling(window=window, center = False).mean() # center = False t avoid data leakage

# %% [markdown]
# Rates of change:

# %%
df = df.copy()
for col in feature_cols:
    for period in [2, 6, 12, 24, 48]:
        df[f'{col}_roc_{period}'] = (df[col] - df[col].shift(period)) / period

# %%
df.head()
# Out:
#                      temperature_2m  relative_humidity_2m  rain  \
# date
# 2017-01-01 02:00:00       19.130999             34.823170   0.0
# 2017-01-01 03:00:00       19.181000             32.453570   0.0
# 2017-01-01 04:00:00       18.681000             33.363396   0.0
# 2017-01-01 05:00:00       17.380999             36.462326   0.0
# 2017-01-01 06:00:00       18.230999             35.558502   0.0
#
#                      cloud_cover_low  cloud_cover_mid  cloud_cover_high  \
# date
# 2017-01-01 02:00:00              0.0              0.0               0.0
# 2017-01-01 03:00:00              0.0              0.0               0.0
# 2017-01-01 04:00:00              0.0              0.0               0.0
# 2017-01-01 05:00:00              0.0              0.0               0.0
# 2017-01-01 06:00:00              0.0              0.0               0.0
#
#                      wind_speed_10m  wind_speed_100m  wind_direction_10m  \
# date
# 2017-01-01 02:00:00        4.393177         8.099383                   9
# 2017-01-01 03:00:00        3.580503         7.379024                   9
# 2017-01-01 04:00:00        2.641969         6.140033                   9
# 2017-01-01 05:00:00        2.247220         4.210700                   2
# 2017-01-01 06:00:00        1.615549         2.860070                   5
#
#                      wind_direction_100m  ...  U_100m_roc_2  U_100m_roc_6  \
# date                                      ...
# 2017-01-01 02:00:00                    9  ...           NaN           NaN
# 2017-01-01 03:00:00                    9  ...           NaN           NaN
# 2017-01-01 04:00:00                    2  ...      0.450001           NaN
# 2017-01-01 05:00:00                    2  ...      1.200001           NaN
# 2017-01-01 06:00:00                    4  ...      2.099997           NaN
#
#                      U_100m_roc_12  U_100m_roc_24  U_100m_roc_48  \
# date
# 2017-01-01 02:00:00            NaN            NaN            NaN
# 2017-01-01 03:00:00            NaN            NaN            NaN
# 2017-01-01 04:00:00            NaN            NaN            NaN
# 2017-01-01 05:00:00            NaN            NaN            NaN
# 2017-01-01 06:00:00            NaN            NaN            NaN
#
#                      wind_shear_magnitude_roc_2  wind_shear_magnitude_roc_6  \
# date
# 2017-01-01 02:00:00                         NaN                         NaN
# 2017-01-01 03:00:00                         NaN                         NaN
# 2017-01-01 04:00:00                   -0.001032                         NaN
# 2017-01-01 05:00:00                   -0.009617                         NaN
# 2017-01-01 06:00:00                   -0.012567                         NaN
#
#                      wind_shear_magnitude_roc_12  wind_shear_magnitude_roc_24  \
# date
# 2017-01-01 02:00:00                          NaN                          NaN
# 2017-01-01 03:00:00                          NaN                          NaN
# 2017-01-01 04:00:00                          NaN                          NaN
# 2017-01-01 05:00:00                          NaN                          NaN
# 2017-01-01 06:00:00                          NaN                          NaN
#
#                      wind_shear_magnitude_roc_48
# date
# 2017-01-01 02:00:00                          NaN
# 2017-01-01 03:00:00                          NaN
# 2017-01-01 04:00:00                          NaN
# 2017-01-01 05:00:00                          NaN
# 2017-01-01 06:00:00                          NaN
#
# [5 rows x 317 columns]

# %%
list(df)
# Out:
# ['temperature_2m',
#  'relative_humidity_2m',
#  'rain',
#  'cloud_cover_low',
#  'cloud_cover_mid',
#  'cloud_cover_high',
#  'wind_speed_10m',
#  'wind_speed_100m',
#  'wind_direction_10m',
#  'wind_direction_100m',
#  'direct_radiation',
#  'diffuse_radiation',
#  'power_x',
#  'TOD',
#  'TOD_sin',
#  'TOD_cos',
#  'wind_speed_ratio',
#  'wind_shear',
#  'U_10m',
#  'V_10m',
#  'U_100m',
#  'V_100m',
#  'wind_shear_magnitude',
#  'temperature_2m_lag_12',
#  'temperature_2m_lag_24',
#  'temperature_2m_lag_48',
#  'temperature_2m_lag_72',
#  'relative_humidity_2m_lag_12',
#  'relative_humidity_2m_lag_24',
#  'relative_humidity_2m_lag_48',
#  'relative_humidity_2m_lag_72',
#  'rain_lag_12',
#  'rain_lag_24',
#  'rain_lag_48',
#  'rain_lag_72',
#  'cloud_cover_low_lag_12',
#  'cloud_cover_low_lag_24',
#  'cloud_cover_low_lag_48',
#  'cloud_cover_low_lag_72',
#  'cloud_cover_mid_lag_12',
#  'cloud_cover_mid_lag_24',
#  'cloud_cover_mid_lag_48',
#  'cloud_cover_mid_lag_72',
#  'cloud_cover_high_lag_12',
#  'cloud_cover_high_lag_24',
#  'cloud_cover_high_lag_48',
#  'cloud_cover_high_lag_72',
#  'wind_speed_10m_lag_12',
#  'wind_speed_10m_lag_24',
#  'wind_speed_10m_lag_48',
#  'wind_speed_10m_lag_72',
#  'wind_speed_100m_lag_12',
#  'wind_speed_100m_lag_24',
#  'wind_speed_100m_lag_48',
#  'wind_speed_100m_lag_72',
#  'wind_direction_10m_lag_12',
#  'wind_direction_10m_lag_24',
#  'wind_direction_10m_lag_48',
#  'wind_direction_10m_lag_72',
#  'wind_direction_100m_lag_12',
#  'wind_direction_100m_lag_24',
#  'wind_direction_100m_lag_48',
#  'wind_direction_100m_lag_72',
#  'direct_radiation_lag_12',
#  'direct_radiation_lag_24',
#  'direct_radiation_lag_48',
#  'direct_radiation_lag_72',
#  'diffuse_radiation_lag_12',
#  'diffuse_radiation_lag_24',
#  'diffuse_radiation_lag_48',
#  'diffuse_radiation_lag_72',
#  'power_x_lag_12',
#  'power_x_lag_24',
#  'power_x_lag_48',
#  'power_x_lag_72',
#  'TOD_lag_12',
#  'TOD_lag_24',
#  'TOD_lag_48',
#  'TOD_lag_72',
#  'TOD_sin_lag_12',
#  'TOD_sin_lag_24',
#  'TOD_sin_lag_48',
#  'TOD_sin_lag_72',
#  'TOD_cos_lag_12',
#  'TOD_cos_lag_24',
#  'TOD_cos_lag_48',
#  'TOD_cos_lag_72',
#  'wind_speed_ratio_lag_12',
#  'wind_speed_ratio_lag_24',
#  'wind_speed_ratio_lag_48',
#  'wind_speed_ratio_lag_72',
#  'wind_shear_lag_12',
#  'wind_shear_lag_24',
#  'wind_shear_lag_48',
#  'wind_shear_lag_72',
#  'U_10m_lag_12',
#  'U_10m_lag_24',
#  'U_10m_lag_48',
#  'U_10m_lag_72',
#  'U_100m_lag_12',
#  'U_100m_lag_24',
#  'U_100m_lag_48',
#  'U_100m_lag_72',
#  'wind_shear_magnitude_lag_12',
#  'wind_shear_magnitude_lag_24',
#  'wind_shear_magnitude_lag_48',
#  'wind_shear_magnitude_lag_72',
#  'temperature_2m_ma_2',
#  'temperature_2m_ma_6',
#  'temperature_2m_ma_12',
#  'temperature_2m_ma_24',
#  'temperature_2m_ma_48',
#  'relative_humidity_2m_ma_2',
#  'relative_humidity_2m_ma_6',
#  'relative_humidity_2m_ma_12',
#  'relative_humidity_2m_ma_24',
#  'relative_humidity_2m_ma_48',
#  'rain_ma_2',
#  'rain_ma_6',
#  'rain_ma_12',
#  'rain_ma_24',
#  'rain_ma_48',
#  'cloud_cover_low_ma_2',
#  'cloud_cover_low_ma_6',
#  'cloud_cover_low_ma_12',
#  'cloud_cover_low_ma_24',
#  'cloud_cover_low_ma_48',
#  'cloud_cover_mid_ma_2',
#  'cloud_cover_mid_ma_6',
#  'cloud_cover_mid_ma_12',
#  'cloud_cover_mid_ma_24',
#  'cloud_cover_mid_ma_48',
#  'cloud_cover_high_ma_2',
#  'cloud_cover_high_ma_6',
#  'cloud_cover_high_ma_12',
#  'cloud_cover_high_ma_24',
#  'cloud_cover_high_ma_48',
#  'wind_speed_10m_ma_2',
#  'wind_speed_10m_ma_6',
#  'wind_speed_10m_ma_12',
#  'wind_speed_10m_ma_24',
#  'wind_speed_10m_ma_48',
#  'wind_speed_100m_ma_2',
#  'wind_speed_100m_ma_6',
#  'wind_speed_100m_ma_12',
#  'wind_speed_100m_ma_24',
#  'wind_speed_100m_ma_48',
#  'wind_direction_10m_ma_2',
#  'wind_direction_10m_ma_6',
#  'wind_direction_10m_ma_12',
#  'wind_direction_10m_ma_24',
#  'wind_direction_10m_ma_48',
#  'wind_direction_100m_ma_2',
#  'wind_direction_100m_ma_6',
#  'wind_direction_100m_ma_12',
#  'wind_direction_100m_ma_24',
#  'wind_direction_100m_ma_48',
#  'direct_radiation_ma_2',
#  'direct_radiation_ma_6',
#  'direct_radiation_ma_12',
#  'direct_radiation_ma_24',
#  'direct_radiation_ma_48',
#  'diffuse_radiation_ma_2',
#  'diffuse_radiation_ma_6',
#  'diffuse_radiation_ma_12',
#  'diffuse_radiation_ma_24',
#  'diffuse_radiation_ma_48',
#  'power_x_ma_2',
#  'power_x_ma_6',
#  'power_x_ma_12',
#  'power_x_ma_24',
#  'power_x_ma_48',
#  'TOD_ma_2',
#  'TOD_ma_6',
#  'TOD_ma_12',
#  'TOD_ma_24',
#  'TOD_ma_48',
#  'TOD_sin_ma_2',
#  'TOD_sin_ma_6',
#  'TOD_sin_ma_12',
#  'TOD_sin_ma_24',
#  'TOD_sin_ma_48',
#  'TOD_cos_ma_2',
#  'TOD_cos_ma_6',
#  'TOD_cos_ma_12',
#  'TOD_cos_ma_24',
#  'TOD_cos_ma_48',
#  'wind_speed_ratio_ma_2',
#  'wind_speed_ratio_ma_6',
#  'wind_speed_ratio_ma_12',
#  'wind_speed_ratio_ma_24',
#  'wind_speed_ratio_ma_48',
#  'wind_shear_ma_2',
#  'wind_shear_ma_6',
#  'wind_shear_ma_12',
#  'wind_shear_ma_24',
#  'wind_shear_ma_48',
#  'U_10m_ma_2',
#  'U_10m_ma_6',
#  'U_10m_ma_12',
#  'U_10m_ma_24',
#  'U_10m_ma_48',
#  'U_100m_ma_2',
#  'U_100m_ma_6',
#  'U_100m_ma_12',
#  'U_100m_ma_24',
#  'U_100m_ma_48',
#  'wind_shear_magnitude_ma_2',
#  'wind_shear_magnitude_ma_6',
#  'wind_shear_magnitude_ma_12',
#  'wind_shear_magnitude_ma_24',
#  'wind_shear_magnitude_ma_48',
#  'temperature_2m_roc_2',
#  'temperature_2m_roc_6',
#  'temperature_2m_roc_12',
#  'temperature_2m_roc_24',
#  'temperature_2m_roc_48',
#  'relative_humidity_2m_roc_2',
#  'relative_humidity_2m_roc_6',
#  'relative_humidity_2m_roc_12',
#  'relative_humidity_2m_roc_24',
#  'relative_humidity_2m_roc_48',
#  'rain_roc_2',
#  'rain_roc_6',
#  'rain_roc_12',
#  'rain_roc_24',
#  'rain_roc_48',
#  'cloud_cover_low_roc_2',
#  'cloud_cover_low_roc_6',
#  'cloud_cover_low_roc_12',
#  'cloud_cover_low_roc_24',
#  'cloud_cover_low_roc_48',
#  'cloud_cover_mid_roc_2',
#  'cloud_cover_mid_roc_6',
#  'cloud_cover_mid_roc_12',
#  'cloud_cover_mid_roc_24',
#  'cloud_cover_mid_roc_48',
#  'cloud_cover_high_roc_2',
#  'cloud_cover_high_roc_6',
#  'cloud_cover_high_roc_12',
#  'cloud_cover_high_roc_24',
#  'cloud_cover_high_roc_48',
#  'wind_speed_10m_roc_2',
#  'wind_speed_10m_roc_6',
#  'wind_speed_10m_roc_12',
#  'wind_speed_10m_roc_24',
#  'wind_speed_10m_roc_48',
#  'wind_speed_100m_roc_2',
#  'wind_speed_100m_roc_6',
#  'wind_speed_100m_roc_12',
#  'wind_speed_100m_roc_24',
#  'wind_speed_100m_roc_48',
#  'wind_direction_10m_roc_2',
#  'wind_direction_10m_roc_6',
#  'wind_direction_10m_roc_12',
#  'wind_direction_10m_roc_24',
#  'wind_direction_10m_roc_48',
#  'wind_direction_100m_roc_2',
#  'wind_direction_100m_roc_6',
#  'wind_direction_100m_roc_12',
#  'wind_direction_100m_roc_24',
#  'wind_direction_100m_roc_48',
#  'direct_radiation_roc_2',
#  'direct_radiation_roc_6',
#  'direct_radiation_roc_12',
#  'direct_radiation_roc_24',
#  'direct_radiation_roc_48',
#  'diffuse_radiation_roc_2',
#  'diffuse_radiation_roc_6',
#  'diffuse_radiation_roc_12',
#  'diffuse_radiation_roc_24',
#  'diffuse_radiation_roc_48',
#  'power_x_roc_2',
#  'power_x_roc_6',
#  'power_x_roc_12',
#  'power_x_roc_24',
#  'power_x_roc_48',
#  'TOD_roc_2',
#  'TOD_roc_6',
#  'TOD_roc_12',
#  'TOD_roc_24',
#  'TOD_roc_48',
#  'TOD_sin_roc_2',
#  'TOD_sin_roc_6',
#  'TOD_sin_roc_12',
#  'TOD_sin_roc_24',
#  'TOD_sin_roc_48',
#  'TOD_cos_roc_2',
#  'TOD_cos_roc_6',
#  'TOD_cos_roc_12',
#  'TOD_cos_roc_24',
#  'TOD_cos_roc_48',
#  'wind_speed_ratio_roc_2',
#  'wind_speed_ratio_roc_6',
#  'wind_speed_ratio_roc_12',
#  'wind_speed_ratio_roc_24',
#  'wind_speed_ratio_roc_48',
#  'wind_shear_roc_2',
#  'wind_shear_roc_6',
#  'wind_shear_roc_12',
#  'wind_shear_roc_24',
#  'wind_shear_roc_48',
#  'U_10m_roc_2',
#  'U_10m_roc_6',
#  'U_10m_roc_12',
#  'U_10m_roc_24',
#  'U_10m_roc_48',
#  'U_100m_roc_2',
#  'U_100m_roc_6',
#  'U_100m_roc_12',
#  'U_100m_roc_24',
#  'U_100m_roc_48',
#  'wind_shear_magnitude_roc_2',
#  'wind_shear_magnitude_roc_6',
#  'wind_shear_magnitude_roc_12',
#  'wind_shear_magnitude_roc_24',
#  'wind_shear_magnitude_roc_48']

# %%
df = df.dropna(how = 'any') # hmm the 48 hour lags are going to cost us a bit of training data, might need to rethink that

# %%
df.to_csv('data/forecast_data_cleaned_feature_engineered.csv')
